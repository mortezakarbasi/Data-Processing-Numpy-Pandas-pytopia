# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# # creating series

# %%
s = pd.Series([1,2,3,4])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# # creating dataframe

# %%
df = pd.DataFrame(
    {
        "Name": ["Ali", "Reza", "Mina", "Sara", "Hassan"],
        "Age": [23,24,35,45,66],
        "City": ["Tehran", "Mahhad", "Shiraz", "Isfehan", "Birjand"]
    }
)

# %%
df
# Out:
#      Name  Age     City
# 0     Ali   23   Tehran
# 1    Reza   24   Mahhad
# 2    Mina   35   Shiraz
# 3    Sara   45  Isfehan
# 4  Hassan   66  Birjand

# %%
df["Name"]
# Out:
# 0       Ali
# 1      Reza
# 2      Mina
# 3      Sara
# 4    Hassan
# Name: Name, dtype: object

# %%
df.iloc[0]
# Out:
# Name       Ali
# Age         23
# City    Tehran
# Name: 0, dtype: object
