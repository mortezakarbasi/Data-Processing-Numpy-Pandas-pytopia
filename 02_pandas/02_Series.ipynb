# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5], index=['a', 'b', 'c', 'd', 'e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# pandas.core.series.Series
#
# library.package.subpackage.class

# %%
pd.Series({
    'a' : 1,
    'b' : 2,
    'c' : 3,
    'd' : 4,
    'e' : 5,
})
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
import numpy as np

# %%
pd.Series(np.array([1, 2, 3, 4, 5]), index=np.array(['a', 'b', 'c', 'd', 'e']))
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
pd.Series(
    [1,2,3,4,5],
    index=['a','b','c','d','e'],
    dtype=np.float64,
    name='example'
)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# Name: example, dtype: float64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape 
# give me tuple
# Out:
# (5,)

# %%
s.size
# give me size
# Out:
# 5

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
s = pd.Series(np.random.rand(100))

# %%
s
# Out:
# 0     0.638963
# 1     0.241462
# 2     0.361137
# 3     0.319817
# 4     0.409606
#         ...
# 95    0.417528
# 96    0.193748
# 97    0.418513
# 98    0.468095
# 99    0.367767
# Length: 100, dtype: float64

# %%
s.head(20)
# Out:
# 0     0.638963
# 1     0.241462
# 2     0.361137
# 3     0.319817
# 4     0.409606
# 5     0.423376
# 6     0.724232
# 7     0.204455
# 8     0.106338
# 9     0.482500
# 10    0.859988
# 11    0.392222
# 12    0.606833
# 13    0.121774
# 14    0.205280
# 15    0.922253
# 16    0.082541
# 17    0.312397
# 18    0.840180
# 19    0.241646
# dtype: float64

# %%
s.tail(3)
# Out:
# 97    0.418513
# 98    0.468095
# 99    0.367767
# dtype: float64

# %%
s.unique()
# Out:
# array([0.6389625 , 0.24146183, 0.3611374 , 0.31981678, 0.40960629,
#        0.42337592, 0.72423245, 0.2044546 , 0.10633772, 0.48249994,
#        0.85998805, 0.39222235, 0.60683323, 0.12177392, 0.2052796 ,
#        0.92225314, 0.08254051, 0.3123967 , 0.84018018, 0.24164576,
#        0.88418651, 0.74205949, 0.32814996, 0.08394844, 0.35577565,
#        0.38563685, 0.28301178, 0.17529419, 0.94911898, 0.16752712,
#        0.24707709, 0.03629347, 0.96537308, 0.58852059, 0.52345239,
#        0.77632999, 0.41378356, 0.65335739, 0.0659076 , 0.12356156,
#        0.62840144, 0.60200746, 0.99654176, 0.21279106, 0.5730272 ,
#        0.24900143, 0.86889097, 0.69478163, 0.98220888, 0.32311188,
#        0.17695816, 0.9951686 , 0.18198118, 0.04566651, 0.85088325,
#        0.32617367, 0.91617414, 0.39737354, 0.56713229, 0.19350659,
#        0.91790464, 0.1790925 , 0.01146715, 0.30247431, 0.45099445,
#        0.69164677, 0.73147046, 0.86275205, 0.81590436, 0.95536039,
# ...

# %%
pd.Series([1,2,2,2]).unique()
# Out:
# array([1, 2])

# %%
s.value_counts()
# Out:
# 0.638963    1
# 0.241462    1
# 0.361137    1
# 0.319817    1
# 0.409606    1
#            ..
# 0.417528    1
# 0.193748    1
# 0.418513    1
# 0.468095    1
# 0.367767    1
# Name: count, Length: 100, dtype: int64

# %%
s.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
s = pd.Series([1, None, None, 2, 3, 4])

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
s.notnull()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# dtype: bool

# %%
~s.isnull()
# it's like not null
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# dtype: bool

# %%
data = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
s = pd.Series(data)

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s['a']
# Out:
# np.int64(1)

# %%
s = pd.Series([1, 2, 3, 4, 5], index=['a', 'a', 'a', 'd', 'e'])

# %%
s['a']
# Out:
# a    1
# a    2
# a    3
# dtype: int64

# %%
# min 22
